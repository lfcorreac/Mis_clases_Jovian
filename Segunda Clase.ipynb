# %% [markdown]
# # Variables y tipos de datos en Python

# %% [markdown]
# Vamos a definir algunas variables que luego usaremos y analizaremos.

# %%
color_favorito="azul"

# %%
color_favorito
# Out:
# 'azul'

# %% [markdown]
# Las variables pueden ser reasignadas.

# %%
color_favorito="rojo"

# %%
color_favorito
# Out:
# 'rojo'

# %% [markdown]
# Una variable previa puede ser usada para reasignarle un nuevo valor. *por ejemplo*

# %%
contador=10

# %%
contador=contador+1

# %%
contador
# Out:
# 11

# %% [markdown]
# Esto se puede abreviar usando `+=` que puede ser `-=` , `*=` o `/=`

# %%
contador=10

# %%
contador+=4

# %%
contador
# Out:
# 14

# %%
contador/=2

# %%
contador
# Out:
# 7.0

# %% [markdown]
# ## Nombrando Variables

# %% [markdown]
# Una variable puede ser corta **i.e**: x, y, z, etc. O puede ser descriptiva( `color_favorito`). Algunas reglas para nombrar variables son:
# 1. El nombre debe empezar por una letra o un subguión. **NUNCA POR UN NUMERO**
# 2. Una variable debe contener letras de a-z, A-Z, 0-9 y _ .
# 3. Los nombres son sensibles a *cambios* de **MAYUSCULA** y **MINUSCULA**.

# %%
una_variable=23
hoy_es_sabado= False
auto_favorito="Suzuki"
tres_mosqueteros=["Athos","Porthos","Aramis"]

# %%
Una_variable
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-661526f22832> in <module>
# ----> 1 Una_variable
#
# NameError: name 'Una_variable' is not defined

# %%
hoy_es_sábado

# %%
3_mosqueteros

# %% [markdown]
# ## Tipos de Variable

# %%
una_variable

# %%
type(una_variable)

# %%
type(hoy_es_sabado)

# %%
type(auto_favorito)

# %%
type(tres_mosqueteros)

# %% [markdown]
# Los tipos de datos más comunes son
# 1. Integer-Int-Entero
# 2. Float-float-flotante
# 3. Boolean
# 4. None
# 5. String
# 6. List
# 7. Tuple
# 8. Dictionary

# %% [markdown]
# *Nota*
# Para cambiar a CODE : Esp + Y
# Para cambiar a markdown : Esc + M

# %% [markdown]
# ## Integer
#
# No contiene comas ni decimales. Va desde el infinito negativo al infinito positivo

# %%
año=2021

# %%
type(año)

# %% [markdown]
# ## Float
#
# Son números con punto decimal. No hay limites en el valor del numero o cantidad de digitos antes o despues del punto decimal.

# %%
pi=3.141592653589793238

# %%
pi

# %%
type(pi)

# %% [markdown]
# *Nota* Si el número contiene parte decimal cero también es flotante.

# %%
un_numero=3.0

# %%
un_numero

# %%
type(un_numero)

# %% [markdown]
# *Nota* Los numeros flotantes tambien pueden ser notaciones cientificas

# %%
otr_numero=1e-2

# %%
otr_numero

# %%
type(otr_numero)

# %% [markdown]
# **OJO**
# Se puede convertir de float a int o viceversa usando ***float*** o ***int ***

# %%
int(pi)

# %%
float(año)

# %%
int(otr_numero)

# %% [markdown]
# ## Operaciones Arimeticas

# %% [markdown]
# Mientras realiza operaciones aritmeticas, **integers** son convertidos en **float** si uno de los operandos es flotante.
# Además el operador division **/** siempre retorna un **flotante** incluso si ambos operadores son integers.
# Usar **//** si queremos que el resultado de la division sea un **int**

# %%
type(2*3.0)

# %%
type(2*3)

# %%
type(10/5)

# %%
10/5

# %% [markdown]
# ## Booleanos

# %% [markdown]
# Representan 2 valores : Verdadero o Falso
# *Nota*
# - **True** tiene el valor de 1
# - **False** tiene el valor de 0

# %%
bool(False)

# %%
bool(0)

# %%
bool(0.0)

# %% [markdown]
# La función Bool a una lista [], diccionario {} o tupla () vacias es False

# %% [markdown]
# ## None

# %% [markdown]
# Indica la ausencia de un valor

# %%
valor=None

# %%
type(valor)

# %% [markdown]
# ## String

# %%
peli_favorita="Mc' Donalds "

# %%
texto='Gracias por explicarme la palabra "manicorto" para mi'

# %%
texto

# %%
texto_1="Gracias por explicarme la palabra \"manicorto\" para mi"

# %%
texto_1

# %% [markdown]
# Los strings creados usando doble comillas deben empezar y terminar en la misma linea. **Usar tres comillas ''' o """**
# para hacerlo multilinea.
# El salto será representado en la salida como \n

# %%
texto_2='''Pedro Castillo: "Cerron no será ni el portero" 
Cerron : "JAJAJAJ" '''

# %%
texto_2

# %%
print(texto_2)

# %% [markdown]
# **Longitud de la cadena** Usamos la funcion ***len***
# Cuenta :
# - Espacios en blanco
# - \n como 1 caracter
# - \" como 1 caracter

# %%
saludo= "Hola Mundo"

# %%
len(saludo)

# %%
saludo_2= """Hola 
mundo"""

# %%
saludo_2

# %%
print(saludo_2)

# %%
len(saludo_2)

# %% [markdown]
# **Convirtiendo el strin en lista**
# Usando funcion ***list***

# %%
list(saludo_2)

# %%
Hoy="Miercoles"

# %% [markdown]
# Indexando una cadena. Los valores van de 0 a n-1 donde n es la longitud de la cadena.

# %%
Hoy[0]

# %%
Hoy[1]

# %%
Hoy[0:5]

# %% [markdown]
# **OJO**
# Puedes verificar si la cadena contiene algún texto usando el operador ***in***

# %%
"M" in Hoy

# %%
"m" in Hoy

# %%
"coles" in Hoy

# %% [markdown]
# Concatenando usando el operador ***+***

# %%
nombre_completo="Luis Correa"
saludo="Hola"

# %%
saludo+nombre_completo

# %%
saludo+" "+nombre_completo

# %% [markdown]
# ## Manipulando los Strings

# %% [markdown]
# Metodos:
#    - **.lower()**
#    - **.upper()**
#    - **.capitalize()**
#    - **.replace()**
#    - **.split()**
#    - **.strip()**
#    - **format()**

# %%
Hoy.lower()

# %%
Hoy.upper()

# %%
Hoy.capitalize() # Cambia el primer caracter a Mayuscula

# %%
today="Saturday"

# %%
today.replace("Wednes","Satur")

# %% [markdown]
# *Nota*
#
# La cadena original no fue modificada

# %%
today

# %%
dias_semana="Lunes,Martes,Miercoles"

# %%
dias_semana
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-36f3164b53ab> in <module>
# ----> 1 dias_semana
#
# NameError: name 'dias_semana' is not defined

# %%
dias_semana.split(",")

# %%
type(dias_semana)

# %%
dias_semana_2=dias_semana.split(",")

# %%
type(dias_semana_2)

# %% [markdown]
# **Quitando espacios en blanco**
# En el inicio y el final pero no en el medio

# %%
linea_texto="    Esta cadena contiene    muchos espacios      "

# %%
linea_texto

# %%
linea_texto.strip()

# %% [markdown]
# **USANDO .FORMAT( )**

# %%
# Agregando variables
costo_mochila=1.25
margen_ganancia=.2
numero_mochilas=500
# Mensajes de salida
mensaje_salida= """Si la tienda vende mochilas a {} por mochila, con una margen de  ganacia de {} %,
entonces la ganancia total por vender {} es {}"""

# %%
print(mensaje_salida)

# %%
ganancia_total=costo_mochila*margen_ganancia*numero_mochilas
mensaje_salida_2=mensaje_salida.format(costo_mochila,margen_ganancia,numero_mochilas,ganancia_total)

# %%
print(mensaje_salida_2)

# %% [markdown]
# **USANDO OPERADOR DE CONCATENACION +**

# %% [markdown]
# Es necesario que los valores a agregar sean strings

# %%
mensaje_salida_3="Si la tienda vende mochilas a " + str(costo_mochila) + " por mochila, con una margen de  ganacia de " + str(margen_ganancia)+" entonces la ganancia total por vender " +str(numero_mochilas)+ " es "+ str(ganancia_total)

# %%
mensaje_salida_3

# %% [markdown]
# ## List

# %%
frutas= ["apple","banana","cherry"]

# %%
type(frutas)
# Out:
# list

# %%
una_lista=[23,"hello",None,3.14,frutas,3<=5]

# %%
una_lista
# Out:
# [23, 'hello', None, 3.14, ['apple', 'banana', 'cherry'], True]

# %%
lista_vacia= []

# %%
len(frutas)
# Out:
# 3

# %%
len(una_lista)
# Out:
# 6

# %%
len(lista_vacia)
# Out:
# 0

# %%
print("Numero de frutas",len(frutas))
# Out:
# Numero de frutas 3

# %% [markdown]
# **Indices en una lista**

# %% [markdown]
# Si el indice es negativo empiza desde el último

# %%
frutas[-1]
# Out:
# 'cherry'

# %%
una_lista[2:5]
# Out:
# [None, 3.14, ['apple', 'banana', 'cherry']]

# %%
frutas.insert(1,"platano")

# %%
frutas
# Out:
# ['apple', 'platano', 'banana', 'cherry']

# %% [markdown]
# ## Manipulando las listas
#
# Metodos
# - **.append()**
# - **.insert()**
# - **.remove()**
# - **.pop()**
# - **.copy()**
# - **,count()**
# - **.index()**

# %%
frutas.append("cereza") # Agrega elemento al último

# %%
frutas.insert(0,"manzana")

# %%
frutas
# Out:
# ['manzana', 'apple', 'platano', 'banana', 'cherry', 'cereza']

# %%
frutas.remove("cereza")

# %%
frutas
# Out:
# ['manzana', 'apple', 'platano', 'banana', 'cherry']

# %%
frutas.pop(0)
# Out:
# 'manzana'

# %%
frutas
# Out:
# ['apple', 'platano', 'banana', 'cherry']

# %%
frutas.pop(1)
# Out:
# 'platano'

# %%
frutas
# Out:
# ['apple', 'banana', 'cherry']

# %%
"pear" in frutas
# Out:
# False

# %%
lista_ext=frutas+["tomato","pear"]

# %%
lista_ext
# Out:
# ['apple', 'banana', 'cherry', 'tomato', 'pear']

# %%
lista_ext_copia=lista_ext.copy()

# %%
lista_ext_copia.remove("cherry")
lista_ext_copia.pop()
lista_ext_copia
# Out:
# ['apple', 'banana', 'tomato']

# %%
lista_ext
# Out:
# ['apple', 'banana', 'cherry', 'tomato', 'pear']

# %%
lista_1=["carro","camioneta","bus"]

# %% [markdown]
# **LA FUNCION COPYEVITA QUE LA SEGUNDA VARIABLE SE ALTERE SI MODIFICAMOS LA ORIGINAL O LA COPIA**

# %%
lista_2=lista_1

# %%
lista_2.pop()
# Out:
# 'bus'

# %%
lista_2
# Out:
# ['carro', 'camioneta']

# %%
lista_1
# Out:
# ['carro', 'camioneta']

# %% [markdown]
# ## TUPLA

# %% [markdown]
# Una tupla es una coleccion ordenada, similar a una lista. Sin embargo no es posible añadir, remover o modificar valores en una tupla. Una tupla es creado por valores encerrados en parentesis y separado por comas.

# %%
fruits=("apple","cherry","dates")

# %%
len(fruits)
# Out:
# 3

# %%
fruits
# Out:
# ('apple', 'cherry', 'dates')

# %%
fruits[0]
# Out:
# 'apple'

# %%
fruits[-2]
# Out:
# 'cherry'

# %%
"dates"in fruits
# Out:
# True

# %% [markdown]
# **TUPLA DE UN SOLO ELEMENTO**

# %%
tuple_single_element=(4,)

# %%
another_tuple_single_element=4,

# %%
tuple_single_element
# Out:
# (4,)

# %%
another_tuple_single_element
# Out:
# (4,)

# %%
no_tupla=4

# %%
no_tupla
# Out:
# 4

# %% [markdown]
# *Nota*
#
# Las tuplas suelen ser usadas para declarar varias variables en una sola

# %%
point=(3,4)

# %%
point_x, point_y =point

# %%
point_x
# Out:
# 3

# %% [markdown]
# **CONVIERTIENDO UNA LISTA EN TUPLA USANDO FUNCION** *TUPLE*

# %%
numbers=["one","two","three"]

# %%
type(numbers)
# Out:
# list

# %%
tuple(numbers)
# Out:
# ('one', 'two', 'three')

# %% [markdown]
# **Una tupla solo cuenta con dos metodos**
# - count
# - index

# %%
a_tuple=(23,"hello",False,None,23,37,"hello")

# %%
type(a_tuple)
# Out:
# tuple

# %%
a_tuple.count("hello")
# Out:
# 2

# %%
a_tuple
# Out:
# (23, 'hello', False, None, 23, 37, 'hello')

# %%
a_tuple.index(False)
# Out:
# 2

# %%
lista_1
# Out:
# ['carro', 'camioneta']

# %% [markdown]
# ## Dictionary

# %% [markdown]
# Un diccionario es una colección desordenada de elementos. Cada elemento almacenado en un diccionario tiene una clave y un valor. Puede utilizar una clave para recuperar el valor correspondiente del diccionario. Los diccionarios tienen el tipo dict.
#
# Los diccionarios se utilizan a menudo para almacenar muchas piezas de información, p. Ej. detalles sobre una persona, en una sola variable. Los diccionarios se crean encerrando pares clave-valor entre llaves o llaves {}.

# %%
person1 = {
    'name': 'Luis',
    'sex': 'Hombre',
    'age': 25,
    'married': True
}

# %%
person1
# Out:
# {'name': 'Luis', 'sex': 'Hombre', 'age': 25, 'married': True}

# %%
person2={"name":"Lucia","sex":"Femenino","age":27,"married": False}

# %%
person1["name"]
# Out:
# 'Luis'

# %%
person2["last name"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-114-dc1a98599616> in <module>
# ----> 1 person2["last name"]
#
# KeyError: 'last name'

# %%
person2.get("last name","No especifica")
# Out:
# 'No especifica'

# %%
"last name" in person2
# Out:
# False

# %%
"Lucia"in person2
# Out:
# False

# %%
person2
# Out:
# {'name': 'Lucia', 'sex': 'Femenino', 'age': 27, 'married': False}

# %%
person2["last name"]="Robledo"

# %%
person2
# Out:
# {'name': 'Lucia',
#  'sex': 'Femenino',
#  'age': 27,
#  'married': False,
#  'last name': 'Robledo'}

# %% [markdown]
# **CLAVES, VALORES E ITEMS**

# %%
person2.keys()
# Out:
# dict_keys(['name', 'sex', 'age', 'married', 'last name'])

# %%
person2.values()
# Out:
# dict_values(['Lucia', 'Femenino', 27, False, 'Robledo'])

# %%
person2.items()
# Out:
# dict_items([('name', 'Lucia'), ('sex', 'Femenino'), ('age', 27), ('married', False), ('last name', 'Robledo')])

# %%
list(person2)
# Out:
# ['name', 'sex', 'age', 'married', 'last name']

# %%
list(person2.values())
# Out:
# ['Lucia', 'Femenino', 27, False, 'Robledo']
