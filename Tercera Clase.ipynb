# %% [markdown]
# # IF , ELSE IF AND ELIF

# %% [markdown]
# - Si se cumple la condición 1, se ejecuta el bloque 1
# - Si no se cumple la condición 1 pero sí que se cumple la condición 2, se ejecuta el bloque 2
# - Si no se cumplen ni la condición 1 ni la condición 2, se ejecuta el bloque 3.
#
# **SE NOTA QUE:** Solo se pueden declarar condiciones en ***if*** y ***elif***

# %%
un_numero=4

# %%
if un_numero % 2 == 0:
    print("Esta linea esta dentro del bloque if")
    print("El número {} es par".format(un_numero))
# Out:
# Esta linea esta dentro del bloque if
# El número 4 es par

# %%
otro_numero=35

# %%
if otro_numero % 2 == 0:
    print("El numero {} es par".format(otro_numero))
else:
    print("El numero {} es impar".format(otro_numero))
# Out:
# El numero 35 es impar

# %%
tres_mosqueteros="Luis","Britney","Piero"

# %%
candidato="Sebastian"

# %%
if candidato in tres_mosqueteros:
    print("{} es un mosquetero".format(candidato))
else:
    print("{} no es un mosquetero".format(candidato))
# Out:
# Sebastian no es un mosquetero

# %% [markdown]
# **Diferencia entre IF Y ELIF**

# %%
a_number=20

# %%
if a_number % 2 == 0:
    print('{} es divisible por 2'.format(a_number))
elif a_number % 3 == 0:
    print('{} es divisible por 3'.format(a_number))
elif a_number % 5 == 0:
    print('{} es divisible por 5'.format(a_number))
elif a_number % 7 == 0:
    print('{} es divisible por 7'.format(a_number))
# Out:
# 20 es divisible por 2

# %%
if a_number % 2 == 0:
    print('{} es divisible por 2'.format(a_number))
if a_number % 3 == 0:
    print('{} es divisible por 3'.format(a_number))
if a_number % 5 == 0:
    print('{} es divisible por 5'.format(a_number))
if a_number % 7 == 0:
    print('{} es divisible por 7'.format(a_number))
# Out:
# 20 es divisible por 2
# 20 es divisible por 5

# %% [markdown]
# **Para que el** *elif* **se ejecute, es necesario que la condicion previa sea negativa o falsa**

# %% [markdown]
# ## Usando IF, ELIF Y ELSE JUNTOS

# %%
a_number=49

# %%
if a_number % 2 == 0:
    print('{} es divisible por 2'.format(a_number))
elif a_number % 3 == 0:
    print('{} es divisible por 3'.format(a_number))
elif a_number % 5 == 0:
    print('{} es divisible por 5'.format(a_number))
else:
    print('Todos las sentencias fallaron')
    print('{} no es divisible por 2, 3 o 5'.format(a_number))
# Out:
# Todos las sentencias fallaron
# 49 no es divisible por 2, 3 o 5

# %%
another_number = 25

# %%
if another_number % 3 == 0 and another_number % 5 == 0:
    print("El número {} es divisible por 3 y 5".format(another_number))
elif another_number % 5 != 0:
    print("El numero {} no es divisible por 5".format(another_number))

# %% [markdown]
# ## Condicionales no Booleanos

# %%
if "":
    print("La condición evaluada es Verdadera")
else:
    print("La condicion evaluada es Falsa")
# Out:
# La condicion evaluada es Falsa

# %%
if "Hello":
    print("La condicion evaluada es verdader")
else:
    print("La condicion evaluada es falsa")
# Out:
# La condicion evaluada es verdader

# %%
if { 'a': 34 }:
    print('The condition evaluted to True')
else:
    print('The condition evaluted to False')
# Out:
# The condition evaluted to True

# %%
if None:
    print('The condition evaluted to True')
else:
    print('The condition evaluted to False')
# Out:
# The condition evaluted to False

# %%
a_number=36

# %%
if a_number % 2 == 0:
    print("{} is even".format(a_number))
    if a_number % 3 == 0:
        print("{} is also divisible by 3".format(a_number))
    else:
        print("{} is not divisibule by 3".format(a_number))
else:
    print("{} is odd".format(a_number))
    if a_number % 5 == 0:
        print("{} is also divisible by 5".format(a_number))
    else:
        print("{} is not divisibule by 5".format(a_number))
# Out:
# 36 is even
# 36 is also divisible by 3

# %% [markdown]
# ## IF ANIDADO

# %%
aleatorio=15

if aleatorio % 2 == 0:
    print("{} es par".format(aleatorio))
    if aleatorio % 3 == 0:
        print("{} es también divisible por 3".format(aleatorio))
    else:
        print("{} no es divisible por 3".format(aleatorio))
else:
    print("{} es impar".format(aleatorio))
    if aleatorio % 5 == 0:
        print("{} es también divisible por 5".format(aleatorio))
    else:
        print("{} no es divisible por 5".format(aleatorio))
# Out:
# 15 es impar
# 15 es también divisible por 5

# %% [markdown]
# ## DECLARACIONES Y VARIABLES - Formas de declarar una condicion
#
# Un caso de uso frecuente de la instrucción if implica probar una condición y establecer el valor de una variable en función de la condición.

# %%
aleatorio_1 = 13

if aleatorio_1 % 2 == 0:
    condicion = 'par'
else:
    condicion = 'impar'

print('El numero {} es {}.'.format(aleatorio_1, condicion))
# Out:
# El numero 13 es impar.

# %% [markdown]
# Otra forma de declarar

# %%
condicion = "par" if aleatorio_1 %2 ==0 else "impar"
print ("el número {} es {}".format(aleatorio_1,condicion))
# Out:
# el número 13 es impar

# %% [markdown]
# ## La declaración PASS

# %% [markdown]
# Si las declaraciones no pueden estar vacías, debe haber al menos una declaración en cada bloque if y elif. Puede usar la instrucción pass para no hacer nada y evitar errores,

# %%
un_numero = 15

# %%
if un_numero%2 ==0:
    pass
else:
    condicion="impar"
    print("{} un numero es {}".format(un_numero,condicion))
# Out:
# 15 un numero es impar

# %% [markdown]
# # ITERACION USANDO WHILE

# %% [markdown]
# Intentemos calcular el factorial de 100 usando un ciclo while. El factorial de un número n es el producto (multiplicación) de todos los números del 1 al n, es decir, 1 * 2 * 3 * ... * (n-2) * (n-1) * n.

# %%
n=1
factorial=1
m=int(input("Calcular el factorial de "))
while n <= m:
    factorial=n*factorial
    n=n+1
print('The factorial de {} is: {}'.format(m,factorial))
# Out:
# Calcular el factorial de 5
# The factorial de 5 is: 120

# %% [markdown]
# Puede verificar cuánto tarda una celda en ejecutarse agregando el comando mágico **%%time** en la parte superior de la celda. Prueba a comprobar cuánto tiempo lleva calcular el factorial de 100, 1000, 10000, 100000, etc.

# %%
# %%time
n=1
factorial=1
while n <= 100:
    factorial=n*factorial
    n=n+1
print('The factorial of 100 is: {}'.format(factorial))
# Out:
# The factorial of 100 is: 93326215443944152681699238856266700490715968264381621468592963895217599993229915608941463976156518286253697920827223758251185210916864000000000000000000000000
# CPU times: user 291 µs, sys: 0 ns, total: 291 µs
# Wall time: 254 µs

# %% [markdown]
# Aquí hay otro ejemplo que usa dos bucles while para crear un patrón interesante.

# %%
line = '*'
max_length = 10

while len(line) <= max_length:
    print(line)
    line += "*" # O line = line + "*"
# Out:
# *
# **
# ***
# ****
# *****
# ******
# *******
# ********
# *********
# **********

# %%
len(line)
# Out:
# 11

# %%
line
# Out:
# '***********'

# %%
line[-4:-2]
# Out:
# '**'

# %%
while len(line)>0:
    line=line[:-1]
    print(line)
# Out:
# **********
# *********
# ********
# *******
# ******
# *****
# ****
# ***
# **
# *

# %%
line = "*"
max_length = 10

while len(line) <= max_length:
    print(line)
    line += "*" # O line = line + "*"
while len(line) > 0:
    print(line)
    line=line[:-1]
# Out:
# *
# **
# ***
# ****
# *****
# ******
# *******
# ********
# *********
# **********
# ***********
# **********
# *********
# ********
# *******
# ******
# *****
# ****
# ***
# **
# *

# %%
line="*"
vacio=" "
espacios=7
xes=1
text=vacio*espacios+line
i=1

while i <= 5:
    print(text)
    espacios=espacios-1
    xes=xes+2
    text= espacios*vacio + xes*line
    i+=1

while i > 0:
    print(text)
    espacios=espacios+1
    xes=xes-2
    text=espacios * vacio + xes*line
    i=i-1
# Out:
#        *
#       ***
#      *****
#     *******
#    *********
#   ***********
#    *********
#     *******
#      *****
#       ***
#        *

# %%
i=1
line="*"
vacios=" "
num_esp=9
espacios=num_esp*vacios
text=espacios+line
print(text)
# Out:
#          *

# %%
while i<=5:
    print(text)
    i=i+1
    num_esp=num_esp-1
    espacios=num_esp*vacios
    text=espacios+i*line
# Out:
#          *
#         **
#        ***
#       ****
#      *****

# %%
i
# Out:
# 6

# %%
while i>0:
    print(text)
    i=i-1
    num_esp=num_esp+1
    espacios=num_esp*vacios
    text=espacios+line*i
# Out:
#     ******
#      *****
#       ****
#        ***
#         **
#          *

# %%
i=1
line="*"
vacios=" "
num_esp=9
espacios=num_esp*vacios
text=espacios+line

while i<=9:
    print(text)
    i=i+1
    num_esp=num_esp-1
    espacios=num_esp*vacios
    text=espacios+i*line

while i>0:
    print(text)
    i=i-1
    num_esp=num_esp+1
    espacios=num_esp*vacios
    text=espacios+line*i
# Out:
#          *
#         **
#        ***
#       ****
#      *****
#     ******
#    *******
#   ********
#  *********
# **********
#  *********
#   ********
#    *******
#     ******
#      *****
#       ****
#        ***
#         **
#          *
