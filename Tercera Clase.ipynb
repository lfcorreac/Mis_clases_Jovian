# %% [markdown]
# # Primeros Pasos con Jupyter: Operadores Logicos

# %% [markdown]
# Algunos atajos útiles para aprender programación en Jupyter.
# - Crear una nueva celda : Esc + B
# - Abrir en Markdown : Esc + M
# - Abrir en Código: Esc + Y
# - Correr una celda : Shift + Enter

# %% [markdown]
# ## Operadores Matemáticos

# %% [markdown]
# Los típicos operadores matemáticos: + , - , * , /
# Algunos no tan típicos como: //,% y **

# %%
2+2+4
# Out:
# 8

# %%
15-10
# Out:
# 5

# %%
4*3
# Out:
# 12

# %%
144/36
# Out:
# 4.0

# %%
144//36
# Out:
# 4

# %%
145//36
# Out:
# 4

# %%
145/36
# Out:
# 4.027777777777778

# %%
145%36
# Out:
# 1

# %%
12**2
# Out:
# 144

# %% [markdown]
# Notamos:
# - // nos devuelve el cociente entero de una division
# - % nos devuelve el residuo de una división
# - ** es el operador potencia

# %%
135//8
# Out:
# 16

# %%
135%16
# Out:
# 7

# %%
16*8
# Out:
# 128

# %%
128+7
# Out:
# 135

# %% [markdown]
# Resolviendo Problema usando variables : Hallaremos la ganancia total de un vendedor de autos con los siguientes datos declarados

# %%
# Datos 
costo_auto=125
margen_ganancia=.2
numero_autos=50
# Formulas que necesitamos
ganancia_x_auto=costo_auto*margen_ganancia
total_ganancia=numero_autos*ganancia_x_auto

# %%
costo_auto
# Out:
# 125

# %%
margen_ganancia
# Out:
# 0.2

# %%
ganancia_x_auto
# Out:
# 25.0

# %%
numero_autos
# Out:
# 50

# %%
total_ganancia
# Out:
# 1250.0

# %% [markdown]
# Es necesario que una variable haya sido declarada antes de ejecutarla

# %% [markdown]
# Mostraremos un mensaje junto a la ganancia total : PRINT

# %%
print("La ganancia total es S/.",total_ganancia)
# Out:
# La ganancia total es S/. 1250.0

# %% [markdown]
# ## Insertando comentarios:
# - Multilineas : """ (Triple comillas)
# - Linea simple : #

# %%
numero_favorito= 25 # Porque es el numero de mi cumpleaños

# %%
cat_A=4
cat_B=3

# Formula n°1
hip=(cat_A**2+cat_B**2)**0.5

# %%
"""Estamos usando un comentario multilinea
la diferencia con la almohadilla o # es que no necesitamos
colocar una cada vez que estemos en otra linea"""

print("La hipotenesa mide: ",hip)
# Out:
# La hipotenesa mide:  5.0

# %% [markdown]
# ## Condicionales en Python

# %% [markdown]
# Los condicionales en python son
# - == : igualdad
# - != : no iguales
# - `>`  : mayor
# - <  : menor
# - `>=`  : mayor igual
# - <=  : menor igual
#
# Sombreamos los > con comilla invertida : ` ` para ello usamos alt + 92

# %%
numero_favorito
# Out:
# 25

# %%
numero_favorito==25
# Out:
# True

# %%
numero_favorito != 30
# Out:
# True

# %%
ganancia_esperada=15000
es_ganancia_esperada_mayor=ganancia_esperada>total_ganancia

# %%
print("Se supero la ganancia esperada en la venta de autos: ",es_ganancia_esperada_mayor)
# Out:
# Se supero la ganancia esperada en la venta de autos:  True

# %% [markdown]
# ## Operadores Lógicos
#
# Son los operadores Verdadero y Falso :
# - TRUE
# - FALSE
